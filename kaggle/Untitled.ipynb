# %% [markdown]
# # Kaggle test
# [20 Years of Games](https://www.kaggle.com/egrinstein/20-years-of-games#)
# [Tutorial](https://www.dataquest.io/blog/pandas-python-tutorial/)

# %%
import pandas as pd

reviews = pd.read_csv("ign.csv")
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
reviews.shape
# Out:
# (18625, 11)

# %%
reviews.iloc[0:5,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
reviews.iloc[9,:]
# Out:
# Unnamed: 0                                                9
# score_phrase                                           Good
# title                             Total War Battles: Shogun
# url               /games/total-war-battles-shogun/pc-142564
# platform                                                 PC
# score                                                     7
# genre                                              Strategy
# editors_choice                                            N
# release_year                                           2012
# release_month                                             9
# release_day                                              11
# Name: 9, dtype: object

# %%
# remove first column, which doesn't have any usefull information
reviews = reviews.iloc[:,1:]
reviews.head()
# Out:
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
reviews.loc[:5,:]
# Out:
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# 5         /games/total-war-battles-shogun/mac-142565         Macintosh    7.0
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# ...

# %%
reviews.loc[:5, "score"] # retrieve column by name with loc method
# Out:
# 0    9.0
# 1    9.0
# 2    8.5
# 3    8.5
# 4    8.5
# 5    7.0
# Name: score, dtype: float64

# %%
reviews.loc[:5, ["score", "release_year"]] # retrieve multi-columns with loc method
# Out:
#    score  release_year
# 0    9.0          2012
# 1    9.0          2012
# 2    8.5          2012
# 3    8.5          2012
# 4    8.5          2012
# 5    7.0          2012

# %%
reviews["score"]
# Out:
# 0         9.0
# 1         9.0
# 2         8.5
# 3         8.5
# 4         8.5
# 5         7.0
# 6         3.0
# 7         9.0
# 8         3.0
# 9         7.0
# 10        7.5
# 11        7.5
# 12        7.0
# 13        9.0
# 14        9.0
# 15        6.5
# 16        6.5
# 17        8.0
# 18        5.5
# 19        7.0
# 20        7.0
# 21        7.5
# 22        7.5
# 23        7.5
# 24        9.0
# 25        7.0
# 26        9.0
# 27        7.5
# 28        8.0
# 29        6.5
#          ...
# 18595     4.4
# 18596     6.5
# 18597     4.9
# 18598     6.8
# 18599     7.0
# 18600     7.4
# 18601     7.4
# 18602     7.4
# 18603     7.8
# 18604     8.6
# 18605     6.0
# 18606     6.4
# 18607     7.0
# 18608     5.4
# 18609     8.0
# 18610     6.0
# 18611     5.8
# 18612     7.8
# 18613     8.0
# 18614     9.2
# 18615     9.2
# 18616     7.5
# 18617     8.4
# 18618     9.1
# 18619     7.9
# 18620     7.6
# 18621     9.0
# 18622     5.8
# 18623    10.0
# 18624    10.0
# ...

# %%
reviews[["score", "release_year"]]
# Out:
#        score  release_year
# 0        9.0          2012
# 1        9.0          2012
# 2        8.5          2012
# 3        8.5          2012
# 4        8.5          2012
# 5        7.0          2012
# 6        3.0          2012
# 7        9.0          2012
# 8        3.0          2012
# 9        7.0          2012
# 10       7.5          2012
# 11       7.5          2012
# 12       7.0          2012
# 13       9.0          2012
# 14       9.0          2012
# 15       6.5          2012
# 16       6.5          2012
# 17       8.0          2012
# 18       5.5          2012
# 19       7.0          2012
# 20       7.0          2012
# 21       7.5          2012
# 22       7.5          2012
# 23       7.5          2012
# 24       9.0          2012
# 25       7.0          2012
# 26       9.0          2012
# 27       7.5          2012
# 28       8.0          2012
# 29       6.5          2012
# ...      ...           ...
# 18595    4.4          2016
# 18596    6.5          2016
# ...

# %%
type(reviews["score"])
# Out:
# pandas.core.series.Series

# %%
type(reviews[["score", "release_year"]])
# Out:
# pandas.core.frame.DataFrame

# %%
s1 = pd.Series([1,2]) # create a series
s1
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s2 = pd.Series(["Boris Yeltsin", "Mikhail Gorbachev"])
s2
# Out:
# 0        Boris Yeltsin
# 1    Mikhail Gorbachev
# dtype: object

# %%
pd.DataFrame([s1, s2])
# Out:
#                0                  1
# 0              1                  2
# 1  Boris Yeltsin  Mikhail Gorbachev

# %%
pd.DataFrame([[1,2],["Boris Yeltsin", "Mikhail Gorbachev"]])
# Out:
#                0                  1
# 0              1                  2
# 1  Boris Yeltsin  Mikhail Gorbachev

# %%
frame = pd.DataFrame(
    [
        [1,2],
        ["Boris Yeltsin", "Mikhail Gorbachev"]
    ],
    index=["row1", "row2"],
    columns=["column1", "column2"]
)
frame
# Out:
#             column1            column2
# row1              1                  2
# row2  Boris Yeltsin  Mikhail Gorbachev

# %%
frame.loc["row1":"row2", "column1"]
# Out:
# row1                1
# row2    Boris Yeltsin
# Name: column1, dtype: object

# %%
reviews = reviews.iloc[:, 1:]
reviews
# Out:
#                                                    title  \
# 0                                LittleBigPlanet PS Vita
# 1      LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                   Splice: Tree of Life
# 3                                                 NHL 13
# 4                                                 NHL 13
# 5                              Total War Battles: Shogun
# 6                                    Double Dragon: Neon
# 7                                           Guild Wars 2
# 8                                    Double Dragon: Neon
# 9                              Total War Battles: Shogun
# 10                               Tekken Tag Tournament 2
# 11                               Tekken Tag Tournament 2
# 12                                            Wild Blood
# 13                                     Mark of the Ninja
# 14                                     Mark of the Ninja
# ...

# %%
reviews["title"].head()
# Out:
# 0                              LittleBigPlanet PS Vita
# 1    LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                                 Splice: Tree of Life
# 3                                               NHL 13
# 4                                               NHL 13
# Name: title, dtype: object

# %%
reviews["score"].mean()
# Out:
# 6.950459060402666

# %%
reviews.mean(axis=1)
# Out:
# 0        510.500
# 1        510.500
# 2        510.375
# 3        510.125
# 4        510.125
# 5        509.750
# 6        508.750
# 7        510.250
# 8        508.750
# 9        509.750
# 10       509.875
# 11       509.875
# 12       509.500
# 13       509.250
# 14       509.250
# 15       508.375
# 16       508.375
# 17       508.500
# 18       507.375
# 19       507.750
# 20       507.750
# 21       514.625
# 22       514.625
# 23       514.625
# 24       515.000
# 25       514.250
# 26       514.750
# 27       514.125
# 28       514.250
# 29       513.625
#           ...
# 18595    510.850
# 18596    510.875
# 18597    510.225
# 18598    510.700
# 18599    510.750
# 18600    512.600
# 18601    512.600
# 18602    512.600
# 18603    512.450
# 18604    512.400
# 18605    511.500
# 18606    508.600
# 18607    510.750
# 18608    510.350
# 18609    510.750
# 18610    510.250
# 18611    508.700
# 18612    509.200
# 18613    508.000
# 18614    515.050
# 18615    515.050
# ...

# %%
reviews.corr()
# Out:
#                   score  release_year  release_month  release_day
# score          1.000000      0.062716       0.007632     0.020079
# release_year   0.062716      1.000000      -0.115515     0.016867
# release_month  0.007632     -0.115515       1.000000    -0.067964
# release_day    0.020079      0.016867      -0.067964     1.000000

# %%
score_filter = reviews["score"] > 7
score_filter
filtered_reviews = reviews[score_filter]
filtered_reviews.head()
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# ...

# %%
xbox_one_filter = (reviews["score"] > 7) & (reviews["platform"] == "Xbox One")
filtered_reviews = reviews[xbox_one_filter]
filtered_reviews.head()
# Out:
#                           title  \
# 17137                 Gone Home
# 17197            Rayman Legends
# 17295  LEGO Marvel Super Heroes
# 17313             Dead Rising 3
# 17317           Killer Instinct
#
#                                                      url  platform  score  \
# 17137                 /games/gone-home/xbox-one-20014361  Xbox One    9.5
# 17197            /games/rayman-legends/xbox-one-20008449  Xbox One    9.5
# 17295  /games/lego-marvel-super-heroes/xbox-one-20000826  Xbox One    9.0
# 17313               /games/dead-rising-3/xbox-one-124306  Xbox One    8.3
# 17317      /games/killer-instinct-2013/xbox-one-20000538  Xbox One    8.4
#
#             genre editors_choice  release_year  release_month  release_day
# 17137  Simulation              Y          2013              8           15
# 17197  Platformer              Y          2013              8           26
# 17295      Action              Y          2013             10           22
# ...

# %%
# setup plotting inside a Jupyter notebook
# %matplotlib inline 
reviews[reviews["platform"] == "Xbox One"]["score"].plot(kind='hist')

# %%
filtered_reviews["score"].hist()
